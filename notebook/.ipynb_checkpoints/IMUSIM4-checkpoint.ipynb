# %%
from networkx import *
from imusim.all import *
model = loadBVHFile('../data/manwalk.bvh', CM_TO_M_CONVERSION)

# %%
model.position(1)
# Out:
# array([[-0.03398059],
#        [-0.03102199],
#        [-0.37603275]])

# %%
model.name
# Out:
# 'Hips'

# %%
model.children

# %%
[child.position(1) for child in model.children]
# Out:
# [array([[-0.02133606],
#        [-0.07919968],
#        [-0.34778315]]),
#  array([[-0.04127539],
#        [ 0.01319287],
#        [-0.34038382]]),
#  array([[-0.03949468],
#        [-0.02947188],
#        [-0.41024748]])]

# %%
[child.name for child in model.children[2].children]
# Out:
# ['LeftCollar', 'RightCollar', 'Neck']

# %%
model.channels
# Out:
# ['Xposition', 'Yposition', 'Zposition', 'Zrotation', 'Xrotation', 'Yrotation']

# %%
model.childJoints

# %%
model.startTime
# Out:
# 0.0

# %%
model.endTime
# Out:
# 6.6668

# %%
t = arange(model.startTime,model.endTime,0.01)

# %%
pg = map(lambda x : model.position(x),t)

# %%
pg = array(pg)

# %%
np.shape(pg)
# Out:
# (667, 3, 1)

# %%
pg[0,:,:]
# Out:
# array([[-0.05008272],
#        [-0.02525769],
#        [-0.37627438]])

# %%
model.position(t[0])
# Out:
# array([[-0.05008272],
#        [-0.02525769],
#        [-0.37627438]])

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(pg[:,0],pg[:,1],pg[:,2])

# %%
c1=model.children
c1

# %%
c2=[c.children for c in c1]

# %%
c2[2]

# %%
c2[0][0].children[0].name
# Out:
# 'LeftAnkle'

# %%
body=nx.Graph()

# %%
model

# %%
model.name
# Out:
# 'Hips'

# %%
d=c1[0]

# %%
d.parent

# %%
tname = []
for n in model.preorderTraversal():
    if n.isJoint:
        tname.append(n.name)
tname
# Out:
# ['Hips',
#  'LeftHip',
#  'LeftKnee',
#  'LeftAnkle',
#  'RightHip',
#  'RightKnee',
#  'RightAnkle',
#  'Chest',
#  'LeftCollar',
#  'LeftShoulder',
#  'LeftElbow',
#  'LeftWrist',
#  'RightCollar',
#  'RightShoulder',
#  'RightElbow',
#  'RightWrist',
#  'Neck',
#  'Head']

# %%
tj =[]
for name in tname:
    print name
    tj.append(model.getJoint(name).position(t))
# Out:
# Hips
# LeftHip
# LeftKnee
# LeftAnkle
# RightHip
# RightKnee
# RightAnkle
# Chest
# LeftCollar
# LeftShoulder
# LeftElbow
# LeftWrist
# RightCollar
# RightShoulder
# RightElbow
# RightWrist
# Neck
# Head

# %%
tj=array(tj)

# %%
np.shape(tj)
# Out:
# (18, 3, 667)

# %%
fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(111, projection='3d')
for k in range(18):
    ax.scatter(tj[k,0,:],tj[k,1,:],tj[k,2,:])
